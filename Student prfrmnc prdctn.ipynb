# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/shaan/Desktop/data analytics/Machine Learning/docs/Student_Performance.csv')

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
cat_data=df.select_dtypes('O')

# %%
cat_data
# Out:
#      Extracurricular Activities
# 0                           Yes
# 1                            No
# 2                           Yes
# 3                           Yes
# 4                            No
# ...                         ...
# 9995                        Yes
# 9996                        Yes
# 9997                        Yes
# 9998                        Yes
# 9999                         No
#
# [10000 rows x 1 columns]

# %%
df.drop('Extracurricular Activities',axis=1,inplace=True)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...

# %%
cat_data
# Out:
#      Extracurricular Activities
# 0                           Yes
# 1                            No
# 2                           Yes
# 3                           Yes
# 4                            No
# ...                         ...
# 9995                        Yes
# 9996                        Yes
# 9997                        Yes
# 9998                        Yes
# 9999                         No
#
# [10000 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
encoded=le.fit_transform(cat_data)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cat_data["Extracurricular Activities"]=encoded

# %%
cat_data
# Out:
#       Extracurricular Activities
# 0                              1
# 1                              0
# 2                              1
# 3                              1
# 4                              0
# ...                          ...
# 9995                           1
# 9996                           1
# 9997                           1
# 9998                           1
# 9999                           0
#
# [10000 rows x 1 columns]

# %%
df=pd.concat([df,cat_data],axis=1)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index  \
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...

# %%
X=df.drop('Performance Index',axis=1)

# %%
X
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Extracurricular Activities
# 0                                    1                           1
# 1                                    2                           0
# 2                                    2                           1
# 3                                    2                           1
# ...

# %%
y=df['Performance Index']

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
xscaled=scaler.fit_transform(X)

# %%
xscaled
# Out:
# array([[ 0.77518771,  1.70417565,  1.45620461, -1.24975394,  1.01045465],
#        [-0.38348058,  0.72391268, -1.49229423, -0.90098215, -0.98965352],
#        [ 1.16141048, -1.06362569,  0.27680507, -0.90098215,  1.01045465],
#        ...,
#        [ 0.38896495,  0.7815752 ,  0.86650484,  0.1453332 ,  1.01045465],
#        [ 1.54763324,  1.5888506 ,  0.27680507, -1.59852572,  1.01045465],
#        [ 0.77518771,  0.26261245,  0.86650484, -1.24975394, -0.98965352]])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xscaled,y,test_size=.2,random_state=2)

# %%
df.size
# Out:
# 60000

# %%
df.shape
# Out:
# (10000, 6)

# %%
xtrain.shape
# Out:
# (8000, 5)

# %%
xtest.shape
# Out:
# (2000, 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 7.38827782, 17.68214574,  0.81930424,  0.56690337,  0.297399  ])

# %%
model.intercept_
# Out:
# 55.2322094772775

# %%
predct=model.predict(xtest)

# %%
predct
# Out:
# array([28.09141683, 35.39557867, 80.43795479, ..., 45.01315301,
#        30.31243483, 68.64738321])

# %%
residual=ytest-predct

# %%
residual
# Out:
# 7878   -2.091417
# 3224   -1.395579
# 1919   -0.437955
# 4432   -3.792531
# 4835    1.066855
#           ...
# 9073   -0.614440
# 8584   -1.144158
# 5390   -1.013153
# 5092    0.687565
# 2964   -1.647383
# Name: Performance Index, Length: 2000, dtype: float64

# %%
import joblib

# %%
joblib.dump(model,'LinearRegression.pkl')
# Out:
# ['LinearRegression.pkl']

# %%
joblib.dump(le,'encoder.pkl')
# Out:
# ['encoder.pkl']

# %%
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']
